# %% [markdown]
# # Exercise 2 - Zaremba small model on Penn Treebank
# ## Stav Bar-Sheshet and Shlomo Spitzer

# %% [markdown]
# # Load Data

# %% [markdown]
# ## Mount Drive
# To load PTB, save and load the trained model

# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# !ls "drive/My Drive/Deep Learning Course/ex2_301558086_305143315/PTB"
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/
# lstm.with_drop.history	     shlomogru_with_drop_model.hdf5
# matar			     shlomogru.with_drop.model.weights.best.hdf5
# ptb.char.test.txt	     shlomogru.without_drop.history
# ptb.char.train.txt	     shlomogru_without_drop_model.hdf5
# ptb.char.valid.txt	     shlomogru.without_drop.model.weights.best.hdf5
# ptb.test.txt		     shlomolstm.with_drop.history
# ptb.train.txt		     shlomolstm_with_drop_model.hdf5
# ptb.valid.txt		     shlomolstm.with_drop.model.weights.best.hdf5
# shlomo			     Stav
# shlomogru.with_drop.history

# %% [markdown]
# ## Load PTB from Github
# Another option to load the PTB data without mounting the drive

# %%
# !git clone https://github.com/wojzaremba/lstm.git
# !ls "lstm/data"
# Out:
# Cloning into 'lstm'...
# remote: Enumerating objects: 53, done.
# remote: Total 53 (delta 0), reused 0 (delta 0), pack-reused 53
# Unpacking objects: 100% (53/53), done.
# ptb.test.txt  ptb.train.txt  ptb.valid.txt

# %% [markdown]
# # Initialize

# %% [markdown]
# ## Data Preprocessing
# PTB data path is defined under 'data_path'.
#
# read_words - convert the PTB text files to lists.
#
# build_vocab - create a dictionary which represent each words in the training set with an id number.
#
# file_to_word_ids - convert a list of words to their ids using the vocabulary dictionary.
#
# load_data - create the training, validation and testing sets using the functions above. In addition, a reverse dictionary is created, in order to check the trained model id prediction results back as words.

# %%
from __future__ import print_function
import collections
import csv
import os
import tensorflow as tf
from time import time
from keras.models import Sequential, load_model
from keras.layers import Dense, Activation, Embedding, Dropout, TimeDistributed, Reshape
from keras.layers import LSTM, GRU, CuDNNLSTM, CuDNNGRU
from keras.optimizers import Adam, SGD
from keras.utils import to_categorical, get_custom_objects
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, Callback, CSVLogger, TensorBoard
from keras.initializers import RandomUniform
from keras import backend as K
from keras import metrics as M
import pandas as pd
import numpy as np

data_path = "drive/My Drive/Deep Learning Course/ex2_301558086_305143315/PTB/"
# data_path = "lstm/data/"

def read_words(filename):
    with tf.gfile.GFile(filename, "r") as f:
        return f.read().replace("\n", "<eos>").split()


def build_vocab(filename):
    data = read_words(filename)

    counter = collections.Counter(data)
    count_pairs = sorted(counter.items(), key=lambda x: (-x[1], x[0]))

    words, _ = list(zip(*count_pairs))
    word_to_id = dict(zip(words, range(len(words))))

    return word_to_id


def file_to_word_ids(filename, word_to_id):
    data = read_words(filename)
    return [word_to_id[word] for word in data if word in word_to_id]


def load_data():
    # get the data paths
    train_path = os.path.join(data_path, "ptb.train.txt")
    valid_path = os.path.join(data_path, "ptb.valid.txt")
    test_path = os.path.join(data_path, "ptb.test.txt")

    # build the complete vocabulary, then convert text data to list of integers
    word_to_id = build_vocab(train_path)
    train_data = file_to_word_ids(train_path, word_to_id)
    valid_data = file_to_word_ids(valid_path, word_to_id)
    test_data = file_to_word_ids(test_path, word_to_id)
    vocabulary = len(word_to_id)
    reversed_dictionary = dict(zip(word_to_id.values(), word_to_id.keys()))

    print('Training data as id example:')
    print(train_data[:5],'\n\n')
    print('Word dictionary:')
    print(word_to_id,'\n\n')
    print('Number of words (in the training set only):')
    print(vocabulary,'\n\n')
    print('Reverse training id examples to words:')
    print(" ".join([reversed_dictionary[x] for x in train_data[:5]]))
    return train_data, valid_data, test_data, vocabulary, reversed_dictionary

train_data, valid_data, test_data, vocabulary, reversed_dictionary = load_data()
# Out:
# Using TensorFlow backend.
# Training data as id example:
# [9970, 9971, 9972, 9974, 9975]
#
#
# Word dictionary:
# {'the': 0, '<unk>': 1, '<eos>': 2, 'N': 3, 'of': 4, 'to': 5, 'a': 6, 'in': 7, 'and': 8, "'s": 9, 'that': 10, 'for': 11, '$': 12, 'is': 13, 'it': 14, 'said': 15, 'on': 16, 'by': 17, 'at': 18, 'as': 19, 'from': 20, 'million': 21, 'with': 22, 'mr.': 23, 'was': 24, 'be': 25, 'are': 26, 'its': 27, 'he': 28, 'but': 29, 'has': 30, 'an': 31, "n't": 32, 'will': 33, 'have': 34, 'new': 35, 'or': 36, 'company': 37, 'they': 38, 'this': 39, 'year': 40, 'which': 41, 'would': 42, 'about': 43, 'says': 44, 'more': 45, 'were': 46, 'market': 47, 'billion': 48, 'his': 49, 'had': 50, 'their': 51, 'up': 52, 'u.s.': 53, 'one': 54, 'than': 55, 'who': 56, 'some': 57, 'been': 58, 'also': 59, 'stock': 60, 'other': 61, 'share': 62, 'not': 63, 'we': 64, 'corp.': 65, 'if': 66, 'when': 67, 'i': 68, 'last': 69, 'president': 70, 'shares': 71, 'years': 72, 'all': 73, 'first': 74, 'two': 75, 'because': 76, 'trading': 77, 'after': 78, 'could': 79, 'inc.': 80, 'sales': 81, '&': 82, 'there': 83, 'out': 84, 'business': 85, 'only': 86, 'do': 87, 'such': 88, 'can': 89, 'most': 90, 'into': 91, 'york': 92, 'may': 93, 'over': 94, 'co.': 95, 'group': 96, 'many': 97, 'government': 98, 'now': 99, 'federal': 100, 'companies': 101, 'no': 102, 'time': 103, 'bank': 104, 'so': 105, 'any': 106, 'cents': 107, 'people': 108, 'quarter': 109, 'you': 110, 'exchange': 111, 'prices': 112, 'even': 113, 'what': 114, 'price': 115, 'investors': 116, 'say': 117, 'down': 118, 'rose': 119, 'while': 120, 'much': 121, 'yesterday': 122, 'week': 123, 'under': 124, 'securities': 125, 'months': 126, 'them': 127, 'bonds': 128, 'big': 129, 'next': 130, 'interest': 131, 'three': 132, 'earlier': 133, "'": 134, 'net': 135, 'earnings': 136, 'major': 137, 'make': 138, 'state': 139, 'american': 140, 'chairman': 141, 'financial': 142, 'did': 143, 'these': 144, 'investment': 145, 'board': 146, 'still': 147, 'through': 148, 'stocks': 149, 'those': 150, 'chief': 151, 'just': 152, 'industry': 153, 'executive': 154, 'since': 155, 'program': 156, 'before': 157, 'rate': 158, 'made': 159, 'officials': 160, 'money': 161, 'national': 162, 'she': 163, 'analysts': 164, 'house': 165, 'like': 166, 'unit': 167, 'month': 168, 'expected': 169, 'off': 170, 'days': 171, 'rates': 172, 'japanese': 173, 'against': 174, 'does': 175, 'plan': 176, 'profit': 177, 'between': 178, 'both': 179, 'capital': 180, 'recent': 181, 'buy': 182, 'income': 183, 'sell': 184, 'issue': 185, 'revenue': 186, 'general': 187, 'get': 188, 'products': 189, 'markets': 190, 'firm': 191, 'back': 192, 'funds': 193, 'own': 194, 'ago': 195, 'average': 196, 'international': 197, 'during': 198, 'her': 199, 'well': 200, 'part': 201, 'fell': 202, 'japan': 203, 'another': 204, 'should': 205, 'higher': 206, 'debt': 207, 'offer': 208, 'take': 209, 'including': 210, 'among': 211, 'court': 212, 'being': 213, 'according': 214, 'each': 215, 'index': 216, 'tax': 217, 'trade': 218, 'world': 219, 'reported': 220, 'work': 221, 'operations': 222, 'then': 223, 'computer': 224, 'past': 225, 'sale': 226, 'however': 227, 'our': 228, 'way': 229, 'lower': 230, 'plans': 231, 'vice': 232, 'economic': 233, 'department': 234, 'end': 235, 'yield': 236, 'report': 237, 'sold': 238, 'insurance': 239, 'growth': 240, 'high': 241, 'how': 242, 'foreign': 243, 'increase': 244, 'less': 245, 'common': 246, 'banks': 247, 'closed': 248, 'several': 249, 'issues': 250, 'where': 251, 'loss': 252, 'very': 253, 'pay': 254, 'yen': 255, 'bush': 256, 'bid': 257, 'five': 258, 'due': 259, 'bill': 260, 'few': 261, 'good': 262, 'used': 263, 'current': 264, 'management': 265, 'early': 266, 'cash': 267, 'oil': 268, 'use': 269, 'costs': 270, 'bond': 271, 'day': 272, 'public': 273, 'system': 274, "'re": 275, 'director': 276, 'third': 277, 'law': 278, 'might': 279, 'traders': 280, 'treasury': 281, 'friday': 282, 'added': 283, 'office': 284, 'city': 285, 'congress': 286, 'concern': 287, 'futures': 288, 'far': 289, 'officer': 290, 'late': 291, 'already': 292, 'fund': 293, 'assets': 294, 'california': 295, 'least': 296 ...
#
#
# Number of words (in the training set only):
# 10000
#
#
# Reverse training id examples to words:
# aer banknote berlitz calloway centrust

# %% [markdown]
# ## Training Object Definition
#
# An instance of the set is defined of a nummber of consecutive words. The instance is defined as a class object.
#
# The object posess the following arguments, data, num_steps, batch_size (defined in the model), vocabulary (number of word in the dictionary - 10000), current_idx and skip_step.
#
# The current_idx is used to make sure that all the data is extracted from the data set, since each set is of a different size. When all the data is extracted from the set, the index is set to 0.
#
# The class constructor is a python generator which creates a list of num_steps input and output (x and y ) instances. A generator allows to iterate the list once and then release it from the memory. This makes the training more memory efficient.

# %%
class BatchGenerator(object):

    def __init__(self, data, num_steps, batch_size, vocabulary, skip_step):
        self.data = data
        self.num_steps = num_steps
        self.batch_size = batch_size
        self.vocabulary = vocabulary
        # this will track the progress of the batches sequentially through the
        # data set - once the data reaches the end of the data set it will reset
        # back to zero
        self.current_idx = 0
        # skip_step is the number of words which will be skipped before the next
        # batch is skimmed from the data set
        self.skip_step = skip_step

    def generate(self):
        x = np.zeros((self.batch_size, self.num_steps))
        y = np.zeros((self.batch_size, self.num_steps, self.vocabulary))
        while True:
            for i in range(self.batch_size):
                if self.current_idx + self.num_steps >= len(self.data):
                    # reset the index back to the start of the data set
                    self.current_idx = 0
                x[i, :] = self.data[self.current_idx:self.current_idx + self.num_steps]
                temp_y = self.data[self.current_idx + 1:self.current_idx + self.num_steps + 1]
                # convert all of temp_y into a one hot representation
                y[i, :, :] = to_categorical(temp_y, num_classes=self.vocabulary)
                self.current_idx += self.skip_step
            yield x, y

# %% [markdown]
# ##Perplexity Definition
#
# Peplexity is used to measure the network's accuracy. Perplexity is simply calculated by power e by the loss. The base e is used since TF used a natural logarithm to calculate the cross entropy.
# The mean of the loss must be calculated in order to get right results.
#
# schedule - is a function used to control the learning rate same as in Zaremba et al. The lr in the small model is reduced by 1.2 factor in 4th epoch and after.

# %%
def perplexity(y_true, y_pred):
    cross_entropy = K.mean(K.categorical_crossentropy(y_true, y_pred))
    perplexity = K.exp(cross_entropy) # since tf uses ln to calc cross_entropy
    return perplexity 
# for some reason this gives wrong values - different from calculating e^cross_entropy
  
def schedule(epoch, lr):
  if epoch + 1  >= 4: # here epochs count from 0
    lr = lr / 2.
  return lr

# %% [markdown]
# ## Model Construction and fitting
#
# The model is based on Zaremba et al. 2015
#
# The "medium" model is used, which has 35 steps (words), minibatches of 20 input sequences and 650 neurons per layer. In the exrecise, 200 neurons are defined.
#
# model_constructor - uses to construct either an LSTM or a GRU model, with or without Dropout regulirization.
#
# The regulirization was used as in Zambera et al., which is applying a p=0.5 dropout only on the non-recurrent connections.
#
# Both the learning rate and dropout probability measures can be changed by the user.
#
# perplexity - uses to calculate the loss as done in Zambera et al. and defined in the exercise.
#
# fitting - gets the net and fitting parameters, fit the network and return the best fitted model and the fitting history.

# %%
def model_constructor(train_data, valid_data, vocabulary, net, num_steps, hidden_size, lr, drp):
    zaremba_init = RandomUniform(minval=-0.1, maxval=0.1)

    model = Sequential()
    model.add(Embedding(vocabulary, hidden_size, input_length=num_steps, embeddings_initializer=zaremba_init))
    if drp > 0.:
        model.add(Dropout(drp))
    if net == 'lstm':
      model.add(CuDNNLSTM(hidden_size, return_sequences=True, kernel_initializer=zaremba_init))
      if drp > 0.:
        model.add(Dropout(drp))
      model.add(CuDNNLSTM(hidden_size, return_sequences=True, kernel_initializer=zaremba_init))
    else:
      model.add(CuDNNGRU(hidden_size, return_sequences=True, kernel_initializer=zaremba_init))
      if drp > 0.:
        model.add(Dropout(drp))
      model.add(CuDNNGRU(hidden_size, return_sequences=True, kernel_initializer=zaremba_init))
    if drp > 0.:
        model.add(Dropout(drp))      
    model.add(TimeDistributed(Dense(vocabulary, kernel_initializer=zaremba_init)))
    model.add(Activation('softmax'))
    
#     zaremba_opt = SGD(lr, momentum=0.0, decay=0.0, nesterov=False, clipnorm = 5.)
    zaremba_opt = Adam(lr, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False, clipnorm = 5.)    
  

    model.compile(loss='categorical_crossentropy', optimizer=zaremba_opt , metrics=[perplexity])

    print(model.summary())
      
    return model
  
def fitting(train_data, valid_data, vocabulary, data_path, name = 'Stav/', net='lstm', num_epochs = 2, lr=0.001, drp = 0.5, num_steps=35, batch_size=20, hidden_size=200):
  
    train_data_generator = BatchGenerator(train_data, num_steps, batch_size, vocabulary,
                                               skip_step=num_steps)
    valid_data_generator = BatchGenerator(valid_data, num_steps, batch_size, vocabulary,
                                               skip_step=num_steps)
    
    model = model_constructor(train_data, valid_data, vocabulary, net, num_steps, hidden_size, lr, drp)
    
    
    if drp > 0.:
      drop='with_drop'
    else:
      drop='without_drop'
    
#     model = load_model(data_path + name + net + '_' + drop + "_model.hdf5", custom_objects={'perplexity': perplexity})

    change_opt = LearningRateScheduler(schedule, verbose=1)
    checkpointer = ModelCheckpoint(filepath= data_path + name + net+'.'+drop+'.model.weights.best.hdf5', verbose = 1, save_best_only=True)
    csv_logger = CSVLogger(filename = data_path + name + net+'.'+drop+'.history.csv', separator=',', append=False) #stream epoc results
    tb_plot = TensorBoard(log_dir='./log/'+name + net + '_' + name, histogram_freq=0,
                         write_graph=False,
                         write_grads=False,
                         batch_size=batch_size,
                         write_images=True)

    history = model.fit_generator(train_data_generator.generate(), len(train_data)//(batch_size*num_steps), num_epochs,
                                  validation_data=valid_data_generator.generate(),
                                  validation_steps=len(valid_data)//(batch_size*num_steps),
                                  callbacks=[checkpointer, csv_logger, tb_plot])

    model.save(data_path + name+ net + '_' + drop + "_model.hdf5")
    
    return history

# %% [markdown]
# ## Check Model and Results
#
# check - gets the fitted model and present the prediction results using the reveresed dictionary.
#
# plot_acc_loss - gets the fitting history and and plots the **perplexity** and loss for both the training and validation sets.

# %%
def check(data_set, num_steps, vocabulary, reversed_dictionary, model):
    dummy_iters = 40
    example_generator = BatchGenerator(data_set, num_steps, 1, vocabulary,
                                                     skip_step=1)
    for i in range(dummy_iters):
        dummy = next(example_generator.generate())
    num_predict = 10
    true_print_out = "Actual words: "
    pred_print_out = "Predicted words: "
    for i in range(num_predict):
        data = next(example_generator.generate())
        prediction = model.predict(data[0])
        predict_word = np.argmax(prediction[:, num_steps-1, :])
        true_print_out += reversed_dictionary[data_set[num_steps + dummy_iters + i]] + " "
        pred_print_out += reversed_dictionary[predict_word] + " "
    print(true_print_out)
    print(pred_print_out)

def check_model(train_data, valid_data, test_data, vocabulary, reversed_dictionary, data_path, name = 'Stav/', net='lstm', drp = 0.5, num_steps=35):
  
    if drp > 0.:
      drop='with_drop'
    else:
      drop='without_drop'
    
    # Load the weights with the best validation accuracy
    model = load_model(data_path + name + net + '_' + drop + "_model.hdf5", custom_objects={'perplexity': perplexity})
    model.load_weights(data_path + name + net+'.'+drop+'.model.weights.best.hdf5')
    
    train_data_generator = BatchGenerator(train_data, num_steps, batch_size, vocabulary,
                                               skip_step=num_steps)
    valid_data_generator = BatchGenerator(valid_data, num_steps, batch_size, vocabulary,
                                               skip_step=num_steps)
    test_data_generator = BatchGenerator(test_data, num_steps, batch_size, vocabulary,
                                               skip_step=num_steps)
    print('\n',"Training data:")
    check(train_data, num_steps, vocabulary, reversed_dictionary, model)
    print('\n',"Validation data:")
    check(valid_data, num_steps, vocabulary, reversed_dictionary, model)
    print('\n',"Test data:")
    check(test_data, num_steps, vocabulary, reversed_dictionary, model)
    
    # Evaluate the model on test set    
    print('\n','Training set evaluation:')
    train_score = model.evaluate_generator(train_data_generator.generate(), len(train_data)//(batch_size*num_steps), verbose=1)
    print('\n','Validation set evaluation:')
    valid_score = model.evaluate_generator(valid_data_generator.generate(), len(valid_data)//(batch_size*num_steps), verbose=1)
    print('\n','Testing set evaluation:')
    test_score = model.evaluate_generator(test_data_generator.generate(), len(test_data)//(batch_size*num_steps), verbose=1)

    # Print test accuracy
    print('\n','Best Model Results:')
    print('Training set perplexity:', np.exp(train_score[0]))
    print('Validation set perplexity:', np.exp(valid_score[0]))
    print('Testing set perplexity:', np.exp(test_score[0]))
    
import matplotlib.pyplot as plt

def plot_acc_lss(data_path, name = 'Stav/', net='lstm', drp=0.5):
    if drp > 0.:
      drop='with_drop'
    else:
      drop='without_drop'
    csv_file = data_path+name+net+'.'+drop+'.history.csv'
    history = pd.read_csv(csv_file)
    x = range(1, len(history['loss'][:])+1)
    
    # summarize history for accuracy
    plt.plot(x,np.exp(history['loss'][:]))
    plt.plot(x,np.exp(history['val_loss'][:]))
    plt.title('model perplexity')
    plt.ylabel('perplexity')
    plt.xlabel('epoch')
    plt.legend(['training', 'validation'], loc='upper left')
    plt.show()
    # summarize history for loss
    plt.plot(x,history['loss'][:])
    plt.plot(x,history['val_loss'][:])
    plt.title('model loss')
    plt.ylabel('categorical_crossentropy')
    plt.xlabel('epoch')
    plt.legend(['training', 'validation'], loc='upper left')
    plt.show()
    
def plot_all(data_path):
  lstm = pd.read_csv(data_path+'/Stav/lstm.without_drop.history.csv')
  lstm_drp = pd.read_csv(data_path+'/Stav/lstm.with_drop.history.csv')
  gru = pd.read_csv(data_path+'/Stav/gru.without_drop.history.csv')
  gru_drp = pd.read_csv(data_path+'/Stav/gru.with_drop.history.csv')
  
  x = range(1, len(lstm['loss'][:])+1)
  
  plt.plot(x,np.exp(lstm['loss'][:]))
  plt.plot(x,np.exp(lstm_drp['loss'][:]))
  plt.plot(x,np.exp(gru['loss'][:]))
  plt.plot(x,np.exp(gru_drp['loss'][:]))
  plt.title('All Models Training Perplexity')
  plt.ylabel('perplexity')
  plt.xlabel('epoch')
  plt.legend(['LSTM', 'LSTM with Dropout', 'GRU', 'GRU with Dropout'], loc='upper right')
  plt.show()

# %% [markdown]
# ## Training Parameters

# %%
num_steps=20
batch_size=20
hidden_size=200
name = 'Stav/'

# %% [markdown]
# # Training

# %% [markdown]
# ## Load TensorBoard

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip
LOG_DIR = './log'

get_ipython().system_raw('tensorboard --logdir {} --host 0.0.0.0 --port 6006 &'.format(LOG_DIR))

get_ipython().system_raw('./ngrok http 6006 &')

# !curl -s http://localhost:4040/api/tunnels | python3 -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
# Out:
# --2018-12-13 21:48:41--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 34.204.22.7, 34.232.181.106, 34.206.36.121, ...
# Connecting to bin.equinox.io (bin.equinox.io)|34.204.22.7|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5363700 (5.1M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip’
#
# ngrok-stable-linux- 100%[===================>]   5.11M  18.3MB/s    in 0.3s
#
# 2018-12-13 21:48:42 (18.3 MB/s) - ‘ngrok-stable-linux-amd64.zip’ saved [5363700/5363700]
#
# Archive:  ngrok-stable-linux-amd64.zip
#   inflating: ngrok
# https://7a272a38.ngrok.io

# %% [markdown]
# ## LSTM Without Dropout

# %%
net = 'lstm'
drp = 0.
lr = 0.001
num_epochs = 15
fitting(train_data, valid_data, vocabulary, data_path, name, net, num_epochs, lr, drp, num_steps, batch_size, hidden_size)
check_model(train_data, valid_data, test_data, vocabulary, reversed_dictionary, data_path, name, net, drp, num_steps)
plot_acc_lss(data_path, name, net, drp)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 20, 200)           2000000
# _________________________________________________________________
# cu_dnnlstm_3 (CuDNNLSTM)     (None, 20, 200)           321600
# _________________________________________________________________
# cu_dnnlstm_4 (CuDNNLSTM)     (None, 20, 200)           321600
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 20, 10000)         2010000
# _________________________________________________________________
# activation_2 (Activation)    (None, 20, 10000)         0
# =================================================================
# Total params: 4,653,200
# Trainable params: 4,653,200
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/15
# 2323/2323 [==============================] - 117s 50ms/step - loss: 6.3493 - perplexity: 661.3337 - val_loss: 5.8213 - val_perplexity: 359.6896
#
# Epoch 00001: val_loss improved from inf to 5.82129, saving model to drive/My Drive/Deep Learning Course/ex2_301558086_305143315/PTB/Stav/lstm.without_drop.model.weights.best.hdf5
# Epoch 2/15
# 2323/2323 [==============================] - 113s 49ms/step - loss: 5.8364 - perplexity: 397.2251 - val_loss: 5.5347 - val_perplexity: 277.8483
#
# Epoch 00002: val_loss improved from 5.82129 to 5.53465, saving model to drive/My Drive/Deep Learning Course/ex2_301558086_305143315/PTB/Stav/lstm.without_drop.model.weights.best.hdf5
# Epoch 3/15
# 2323/2323 [==============================] - 112s 48ms/step - loss: 5.6443 - perplexity: 351.6099 - val_loss: 5.4013 - val_perplexity: 245.3058
#
# Epoch 00003: val_loss improved from 5.53465 to 5.40132, saving model to drive/My Drive/Deep Learning Course/ex2_301558086_305143315/PTB/Stav/lstm.without_drop.model.weights.best.hdf5
# Epoch 4/15
# 2323/2323 [==============================] - 112s 48ms/step - loss: 5.4626 - perplexity: 303.4849 - val_loss: 5.3243 - val_perplexity: 227.9583
#
# Epoch 00004: val_loss improved from 5.40132 to 5.32429, saving model to drive/My Drive/Deep Learning Course/ex2_301558086_305143315/PTB/Stav/lstm.without_drop.model.weights.best.hdf5
# Epoch 5/15
# 2323/2323 [==============================] - 113s 49ms/step - loss: 5.3964 - perplexity: 301.0140 - val_loss: 5.2902 - val_perplexity: 232.3718
#
# Epoch 00005: val_loss improved from 5.32429 to 5.29024, saving model to drive/My Drive/Deep Learning Course/ex2_301558086_305143315/PTB/Stav/lstm.without_drop.model.weights.best.hdf5
# Epoch 6/15
# 2323/2323 [==============================] - 115s 50ms/step - loss: 5.2242 - perplexity: 270.1760 - val_loss: 5.2156 - val_perplexity: 219.4279
#
# Epoch 00006: val_loss improved from 5.29024 to 5.21555, saving model to drive/My Drive/Deep Learning Course/ex2_301558086_305143315/PTB/Stav/lstm.without_drop.model.weights.best.hdf5
# Epoch 7/15
# 2323/2323 [==============================] - 113s 49ms/step - loss: 5.1249 - perplexity: 262.8823 - val_loss: 5.1690 - val_perplexity: 200.5382
#
# Epoch 00007: val_loss improved from 5.21555 to 5.16898, saving model to drive/My Drive/Deep Learning Course/ex2_301558086_305143315/PTB/Stav/lstm.without_drop.model.weights.best.hdf5
# Epoch 8/15
# 2323/2323 [==============================] - 113s 49ms/step - loss: 5.0189 - perplexity: 239.4448 - val_loss: 5.1754 - val_perplexity: 204.7406
#
# Epoch 00008: val_loss did not improve from 5.16898
# Epoch 9/15
# 2323/2323 [==============================] - 113s 48ms/step - loss: 5.0042 - perplexity: 256.4253 - val_loss: 5.1777 - val_perplexity: 208.3690
#
# Epoch 00009: val_loss did not improve from 5.16898
# Epoch 10/15
# 2323/2323 [==============================] - 113s 49ms/step - loss: 4.9031 - perplexity: 239.5537 - val_loss: 5.1692 - val_perplexity: 206.8854
#
# Epoch 00010: val_loss did not improve from 5.16898
# Epoch 11/15
# 2323/2323 [==============================] - 114s 49ms/step - loss: 4.8523 - perplexity: 232.8368 - val_loss: 5.1604 - val_perplexity: 216.1530
#
# Epoch 00011: val_loss improved from 5.16898 to 5.16042, saving model to drive/My Drive/Deep Learning Course/ex2_301558086_305143315/PTB/Stav/lstm.without_drop.model.weights.best.hdf5
# Epoch 12/15
# 2323/2323 [==============================] - 114s 49ms/step - loss: 4.7796 - perplexity: 222.6448 - val_loss: 5.1726 - val_perplexity: 226.1939
#
# Epoch 00012: val_loss did not improve from 5.16042
# Epoch 13/15
# 2323/2323 [==============================] - 114s 49ms/step - loss: 4.7239 - perplexity: 217.2592 - val_loss: 5.1951 - val_perplexity: 224.0023
#
# Epoch 00013: val_loss did not improve from 5.16042
# Epoch 14/15
# 2323/2323 [==============================] - 113s 49ms/step - loss: 4.6788 - perplexity: 220.2718 - val_loss: 5.1692 - val_perplexity: 207.1289
#
# Epoch 00014: val_loss did not improve from 5.16042
# Epoch 15/15
# 2323/2323 [==============================] - 114s 49ms/step - loss: 4.6671 - perplexity: 227.8950 - val_loss: 5.2346 - val_perplexity: 246.7434
#
# Epoch 00015: val_loss did not improve from 5.16042
#
#  Training data:
# Actual words: chairman of consolidated gold fields plc was named a nonexecutive
# Predicted words: president of the <unk> corp. a a named president <unk>
#
#  Validation data:
# Actual words: on various <unk> issues <eos> and the new syndicated reality
# Predicted words: to the <unk> <eos> <eos> the the company york <unk>
#
#  Test data:
# Actual words: unable to cool the selling panic in both stocks and
# Predicted words: <eos> to <unk> the <unk> of <eos> the the <eos>
#
#  Training set evaluation:
# 2323/2323 [==============================] - 55s 24ms/step
#
#  Validation set evaluation:
# 184/184 [==============================] - 4s 24ms/step
#
#  Testing set evaluation:
# 206/206 [==============================] - 5s 24ms/step
#
#  Best Model Results:
# Training set perplexity: 122.9721584243271
# Validation set perplexity: 202.6942189091541
# Testing set perplexity: 210.6643448065894

# %% [markdown]
# ## LSTM With Dropout

# %%
net = 'lstm'
drp = 0.5
lr = 0.001
num_epochs = 20
fitting(train_data, valid_data, vocabulary, data_path, name, net, num_epochs, lr, drp, num_steps, batch_size, hidden_size)
check_model(train_data, valid_data, test_data, vocabulary, reversed_dictionary, data_path, name, net, drp, num_steps)
plot_acc_lss(data_path, name, net, drp)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 20, 200)           2000000
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 20, 200)           0
# _________________________________________________________________
# cu_dnnlstm_1 (CuDNNLSTM)     (None, 20, 200)           321600
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 20, 200)           0
# _________________________________________________________________
# cu_dnnlstm_2 (CuDNNLSTM)     (None, 20, 200)           321600
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 20, 200)           0
# _________________________________________________________________
# time_distributed_3 (TimeDist (None, 20, 10000)         2010000
# _________________________________________________________________
# activation_3 (Activation)    (None, 20, 10000)         0
# =================================================================
# Total params: 4,653,200
# Trainable params: 4,653,200
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/20
# 2323/2323 [==============================] - 145s 62ms/step - loss: 6.5358 - perplexity: 770.3020 - val_loss: 6.0890 - val_perplexity: 467.1951
#
# Epoch 00001: val_loss improved from inf to 6.08898, saving model to drive/My Drive/Deep Learning Course/ex2_301558086_305143315/PTB/Stav/lstm.with_drop.model.weights.best.hdf5
# Epoch 2/20
# 2323/2323 [==============================] - 142s 61ms/step - loss: 6.2694 - perplexity: 566.3834 - val_loss: 5.8845 - val_perplexity: 382.6366
#
# Epoch 00002: val_loss improved from 6.08898 to 5.88454, saving model to drive/My Drive/Deep Learning Course/ex2_301558086_305143315/PTB/Stav/lstm.with_drop.model.weights.best.hdf5
# Epoch 3/20
# 2323/2323 [==============================] - 143s 61ms/step - loss: 6.1416 - perplexity: 512.1615 - val_loss: 5.6883 - val_perplexity: 318.0604
#
# Epoch 00003: val_loss improved from 5.88454 to 5.68831, saving model to drive/My Drive/Deep Learning Course/ex2_301558086_305143315/PTB/Stav/lstm.with_drop.model.weights.best.hdf5
# Epoch 4/20
# 2323/2323 [==============================] - 143s 62ms/step - loss: 6.0975 - perplexity: 499.2401 - val_loss: 5.6209 - val_perplexity: 298.0362
#
# Epoch 00004: val_loss improved from 5.68831 to 5.62088, saving model to drive/My Drive/Deep Learning Course/ex2_301558086_305143315/PTB/Stav/lstm.with_drop.model.weights.best.hdf5
# Epoch 5/20
# 2323/2323 [==============================] - 143s 61ms/step - loss: 6.0268 - perplexity: 471.8389 - val_loss: 5.5709 - val_perplexity: 285.0494
#
# Epoch 00005: val_loss improved from 5.62088 to 5.57094, saving model to drive/My Drive/Deep Learning Course/ex2_301558086_305143315/PTB/Stav/lstm.with_drop.model.weights.best.hdf5
# Epoch 6/20
# 2323/2323 [==============================] - 143s 62ms/step - loss: 6.0064 - perplexity: 465.7442 - val_loss: 5.5665 - val_perplexity: 283.9244
#
# Epoch 00006: val_loss improved from 5.57094 to 5.56650, saving model to drive/My Drive/Deep Learning Course/ex2_301558086_305143315/PTB/Stav/lstm.with_drop.model.weights.best.hdf5
# Epoch 7/20
# 2323/2323 [==============================] - 143s 61ms/step - loss: 5.9355 - perplexity: 440.9726 - val_loss: 5.4658 - val_perplexity: 259.0646
#
# Epoch 00007: val_loss improved from 5.56650 to 5.46577, saving model to drive/My Drive/Deep Learning Course/ex2_301558086_305143315/PTB/Stav/lstm.with_drop.model.weights.best.hdf5
# Epoch 8/20
# 2323/2323 [==============================] - 145s 63ms/step - loss: 5.9032 - perplexity: 436.1516 - val_loss: 5.6071 - val_perplexity: 297.2755
#
# Epoch 00008: val_loss did not improve from 5.46577
# Epoch 9/20
# 2323/2323 [==============================] - 153s 66ms/step - loss: 5.9076 - perplexity: 446.4958 - val_loss: 5.5478 - val_perplexity: 282.2922
#
# Epoch 00009: val_loss did not improve from 5.46577
# Epoch 10/20
# 2323/2323 [==============================] - 147s 63ms/step - loss: 5.8668 - perplexity: 428.2672 - val_loss: 5.5343 - val_perplexity: 274.4833
#
# Epoch 00010: val_loss did not improve from 5.46577
# Epoch 11/20
# 2323/2323 [==============================] - 149s 64ms/step - loss: 5.8352 - perplexity: 425.2681 - val_loss: 5.5190 - val_perplexity: 275.7530
#
# Epoch 00011: val_loss did not improve from 5.46577
# Epoch 12/20
# 2323/2323 [==============================] - 143s 62ms/step - loss: 5.8442 - perplexity: 417.2891 - val_loss: 5.4116 - val_perplexity: 247.0753
#
# Epoch 00012: val_loss improved from 5.46577 to 5.41165, saving model to drive/My Drive/Deep Learning Course/ex2_301558086_305143315/PTB/Stav/lstm.with_drop.model.weights.best.hdf5
# Epoch 13/20
# 2323/2323 [==============================] - 143s 61ms/step - loss: 5.8260 - perplexity: 408.6233 - val_loss: 5.3445 - val_perplexity: 231.4515
#
# Epoch 00013: val_loss improved from 5.41165 to 5.34453, saving model to drive/My Drive/Deep Learning Course/ex2_301558086_305143315/PTB/Stav/lstm.with_drop.model.weights.best.hdf5
# Epoch 14/20
# 2323/2323 [==============================] - 148s 64ms/step - loss: 5.7943 - perplexity: 411.3349 - val_loss: 5.4174 - val_perplexity: 249.2589
#
# Epoch 00014: val_loss did not improve from 5.34453
# Epoch 15/20
# 2323/2323 [==============================] - 146s 63ms/step - loss: 5.8259 - perplexity: 414.0885 - val_loss: 5.3640 - val_perplexity: 235.9916
#
# Epoch 00015: val_loss did not improve from 5.34453
# Epoch 16/20
# 2323/2323 [==============================] - 144s 62ms/step - loss: 5.7847 - perplexity: 398.9084 - val_loss: 5.3586 - val_perplexity: 234.8537
#
# Epoch 00016: val_loss did not improve from 5.34453
# Epoch 17/20
# 2323/2323 [==============================] - 143s 62ms/step - loss: 5.7696 - perplexity: 394.7018 - val_loss: 5.2638 - val_perplexity: 215.1563
#
# Epoch 00017: val_loss improved from 5.34453 to 5.26378, saving model to drive/My Drive/Deep Learning Course/ex2_301558086_305143315/PTB/Stav/lstm.with_drop.model.weights.best.hdf5
# Epoch 18/20
# 2323/2323 [==============================] - 143s 61ms/step - loss: 5.7301 - perplexity: 378.4231 - val_loss: 5.2754 - val_perplexity: 216.9090
#
# Epoch 00018: val_loss did not improve from 5.26378
# Epoch 19/20
# 2323/2323 [==============================] - 142s 61ms/step - loss: 5.7640 - perplexity: 394.2225 - val_loss: 5.1968 - val_perplexity: 201.5281
#
# Epoch 00019: val_loss improved from 5.26378 to 5.19679, saving model to drive/My Drive/Deep Learning Course/ex2_301558086_305143315/PTB/Stav/lstm.with_drop.model.weights.best.hdf5
# Epoch 20/20
# 2323/2323 [==============================] - 143s 62ms/step - loss: 5.7777 - perplexity: 399.1781 - val_loss: 5.2889 - val_perplexity: 219.8822
#
# Epoch 00020: val_loss did not improve from 5.19679
#
#  Training data:
# Actual words: chairman of consolidated gold fields plc was named a nonexecutive
# Predicted words: <unk> of the <unk> inc. in said named president <unk>
#
#  Validation data:
# Actual words: on various <unk> issues <eos> and the new syndicated reality
# Predicted words: <eos> the <unk> <eos> <eos> the the <unk> york <unk>
#
#  Test data:
# Actual words: unable to cool the selling panic in both stocks and
# Predicted words: <eos> to be the <unk> of <eos> the the <eos>
#
#  Training set evaluation:
# 2323/2323 [==============================] - 62s 27ms/step
#
#  Validation set evaluation:
# 184/184 [==============================] - 5s 26ms/step
#
#  Testing set evaluation:
# 206/206 [==============================] - 5s 26ms/step
#
#  Best Model Results:
# Training set perplexity: 234.81440224562922
# Validation set perplexity: 272.33764097564494
# Testing set perplexity: 251.9778629500025

# %% [markdown]
# ## GRU Without Dropout

# %%
net = 'gru'
drp = 0.0
lr = 0.001
num_epochs = 15
fitting(train_data, valid_data, vocabulary, data_path, name, net, num_epochs, lr, drp, num_steps, batch_size, hidden_size)
check_model(train_data, valid_data, test_data, vocabulary, reversed_dictionary, data_path, name, net, drp, num_steps)
plot_acc_lss(data_path, name, net, drp)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 20, 200)           2000000
# _________________________________________________________________
# cu_dnngru_1 (CuDNNGRU)       (None, 20, 200)           241200
# _________________________________________________________________
# cu_dnngru_2 (CuDNNGRU)       (None, 20, 200)           241200
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 20, 10000)         2010000
# _________________________________________________________________
# activation_2 (Activation)    (None, 20, 10000)         0
# =================================================================
# Total params: 4,492,400
# Trainable params: 4,492,400
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/15
# 2323/2323 [==============================] - 139s 60ms/step - loss: 6.6853 - perplexity: 877.2901 - val_loss: 6.1766 - val_perplexity: 511.4856
#
# Epoch 00001: val_loss improved from inf to 6.17660, saving model to drive/My Drive/Deep Learning Course/ex2_301558086_305143315/PTB/Stav/gru.without_drop.model.weights.best.hdf5
# Epoch 2/15
# 2323/2323 [==============================] - 137s 59ms/step - loss: 6.0914 - perplexity: 507.7421 - val_loss: 5.7076 - val_perplexity: 333.2335
#
# Epoch 00002: val_loss improved from 6.17660 to 5.70758, saving model to drive/My Drive/Deep Learning Course/ex2_301558086_305143315/PTB/Stav/gru.without_drop.model.weights.best.hdf5
# Epoch 3/15
# 2323/2323 [==============================] - 137s 59ms/step - loss: 5.7845 - perplexity: 412.1256 - val_loss: 5.3475 - val_perplexity: 235.5911
#
# Epoch 00003: val_loss improved from 5.70758 to 5.34752, saving model to drive/My Drive/Deep Learning Course/ex2_301558086_305143315/PTB/Stav/gru.without_drop.model.weights.best.hdf5
# Epoch 4/15
# 2323/2323 [==============================] - 140s 60ms/step - loss: 5.6270 - perplexity: 374.3871 - val_loss: 5.2785 - val_perplexity: 227.4571
#
# Epoch 00004: val_loss improved from 5.34752 to 5.27851, saving model to drive/My Drive/Deep Learning Course/ex2_301558086_305143315/PTB/Stav/gru.without_drop.model.weights.best.hdf5
# Epoch 5/15
# 2323/2323 [==============================] - 139s 60ms/step - loss: 5.5191 - perplexity: 352.2436 - val_loss: 5.3881 - val_perplexity: 247.3124
#
# Epoch 00005: val_loss did not improve from 5.27851
# Epoch 6/15
# 2323/2323 [==============================] - 140s 60ms/step - loss: 5.4322 - perplexity: 334.0379 - val_loss: 5.4581 - val_perplexity: 269.7005
#
# Epoch 00006: val_loss did not improve from 5.27851
# Epoch 7/15
# 2323/2323 [==============================] - 136s 59ms/step - loss: 5.2953 - perplexity: 299.2037 - val_loss: 5.3848 - val_perplexity: 248.6113
#
# Epoch 00007: val_loss did not improve from 5.27851
# Epoch 8/15
# 2323/2323 [==============================] - 135s 58ms/step - loss: 5.2305 - perplexity: 295.8369 - val_loss: 5.3717 - val_perplexity: 244.4753
#
# Epoch 00008: val_loss did not improve from 5.27851
# Epoch 9/15
# 2323/2323 [==============================] - 139s 60ms/step - loss: 5.2046 - perplexity: 297.2369 - val_loss: 5.3264 - val_perplexity: 241.1486
#
# Epoch 00009: val_loss did not improve from 5.27851
# Epoch 10/15
# 2323/2323 [==============================] - 140s 60ms/step - loss: 5.1218 - perplexity: 282.2095 - val_loss: 5.4424 - val_perplexity: 263.4240
#
# Epoch 00010: val_loss did not improve from 5.27851
# Epoch 11/15
# 2323/2323 [==============================] - 140s 60ms/step - loss: 5.0984 - perplexity: 271.4256 - val_loss: 5.4652 - val_perplexity: 286.0618
#
# Epoch 00011: val_loss did not improve from 5.27851
# Epoch 12/15
# 2323/2323 [==============================] - 141s 61ms/step - loss: 5.0017 - perplexity: 264.4865 - val_loss: 5.4365 - val_perplexity: 268.0835
#
# Epoch 00012: val_loss did not improve from 5.27851
# Epoch 13/15
# 2323/2323 [==============================] - 142s 61ms/step - loss: 5.0128 - perplexity: 265.3386 - val_loss: 5.4175 - val_perplexity: 269.4901
#
# Epoch 00013: val_loss did not improve from 5.27851
# Epoch 14/15
# 2323/2323 [==============================] - 145s 62ms/step - loss: 4.9170 - perplexity: 251.3461 - val_loss: 5.3694 - val_perplexity: 259.9467
#
# Epoch 00014: val_loss did not improve from 5.27851
# Epoch 15/15
# 2323/2323 [==============================] - 145s 62ms/step - loss: 4.8587 - perplexity: 247.3539 - val_loss: 5.5241 - val_perplexity: 304.4950
#
# Epoch 00015: val_loss did not improve from 5.27851
#
#  Training data:
# Actual words: chairman of consolidated gold fields plc was named a nonexecutive
# Predicted words: chairman of the <unk> corp. <unk> 's a <unk> <unk>
#
#  Validation data:
# Actual words: on various <unk> issues <eos> and the new syndicated reality
# Predicted words: to the <unk> and <eos> the the <unk> york <unk>
#
#  Test data:
# Actual words: unable to cool the selling panic in both stocks and
# Predicted words: <eos> to <unk> the <unk> of <eos> the the <eos>
#
#  Training set evaluation:
# 2323/2323 [==============================] - 64s 28ms/step
#
#  Validation set evaluation:
# 184/184 [==============================] - 5s 29ms/step
#
#  Testing set evaluation:
# 206/206 [==============================] - 6s 28ms/step
#
#  Best Model Results:
# Training set perplexity: 221.35335191327832
# Validation set perplexity: 268.4315158880984
# Testing set perplexity: 248.28620635050925

# %% [markdown]
# ## GRU With Dropout

# %%
net = 'gru'
drp = 0.5
lr = 0.001
num_epochs = 20
fitting(train_data, valid_data, vocabulary, data_path, name, net, num_epochs, lr, drp, num_steps, batch_size, hidden_size)
check_model(train_data, valid_data, test_data, vocabulary, reversed_dictionary, data_path, name, net, drp, num_steps)
plot_acc_lss(data_path, name, net, drp)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 20, 200)           2000000
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 20, 200)           0
# _________________________________________________________________
# cu_dnngru_3 (CuDNNGRU)       (None, 20, 200)           241200
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 20, 200)           0
# _________________________________________________________________
# cu_dnngru_4 (CuDNNGRU)       (None, 20, 200)           241200
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 20, 200)           0
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 20, 10000)         2010000
# _________________________________________________________________
# activation_2 (Activation)    (None, 20, 10000)         0
# =================================================================
# Total params: 4,492,400
# Trainable params: 4,492,400
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/20
# 2323/2323 [==============================] - 152s 66ms/step - loss: 6.7892 - perplexity: 972.8533 - val_loss: 6.2925 - val_perplexity: 567.4717
#
# Epoch 00001: val_loss improved from inf to 6.29249, saving model to drive/My Drive/Deep Learning Course/ex2_301558086_305143315/PTB/Stav/gru.with_drop.model.weights.best.hdf5
# Epoch 2/20
# 2323/2323 [==============================] - 151s 65ms/step - loss: 6.3286 - perplexity: 603.5743 - val_loss: 6.0054 - val_perplexity: 428.3656
#
# Epoch 00002: val_loss improved from 6.29249 to 6.00541, saving model to drive/My Drive/Deep Learning Course/ex2_301558086_305143315/PTB/Stav/gru.with_drop.model.weights.best.hdf5
# Epoch 3/20
# 2323/2323 [==============================] - 152s 65ms/step - loss: 6.2044 - perplexity: 548.8610 - val_loss: 5.8955 - val_perplexity: 387.7112
#
# Epoch 00003: val_loss improved from 6.00541 to 5.89554, saving model to drive/My Drive/Deep Learning Course/ex2_301558086_305143315/PTB/Stav/gru.with_drop.model.weights.best.hdf5
# Epoch 4/20
# 2323/2323 [==============================] - 152s 65ms/step - loss: 6.1012 - perplexity: 514.6880 - val_loss: 5.7719 - val_perplexity: 344.6979
#
# Epoch 00004: val_loss improved from 5.89554 to 5.77187, saving model to drive/My Drive/Deep Learning Course/ex2_301558086_305143315/PTB/Stav/gru.with_drop.model.weights.best.hdf5
# Epoch 5/20
# 2323/2323 [==============================] - 154s 66ms/step - loss: 6.0736 - perplexity: 505.3911 - val_loss: 5.7488 - val_perplexity: 335.8240
#
# Epoch 00005: val_loss improved from 5.77187 to 5.74876, saving model to drive/My Drive/Deep Learning Course/ex2_301558086_305143315/PTB/Stav/gru.with_drop.model.weights.best.hdf5
# Epoch 6/20
# 2323/2323 [==============================] - 151s 65ms/step - loss: 6.0043 - perplexity: 479.9441 - val_loss: 5.6781 - val_perplexity: 316.9718
#
# Epoch 00006: val_loss improved from 5.74876 to 5.67814, saving model to drive/My Drive/Deep Learning Course/ex2_301558086_305143315/PTB/Stav/gru.with_drop.model.weights.best.hdf5
# Epoch 7/20
# 2323/2323 [==============================] - 152s 66ms/step - loss: 5.9793 - perplexity: 470.1132 - val_loss: 5.5940 - val_perplexity: 296.1984
#
# Epoch 00007: val_loss improved from 5.67814 to 5.59397, saving model to drive/My Drive/Deep Learning Course/ex2_301558086_305143315/PTB/Stav/gru.with_drop.model.weights.best.hdf5
# Epoch 8/20
# 2323/2323 [==============================] - 151s 65ms/step - loss: 5.9634 - perplexity: 462.1927 - val_loss: 5.6465 - val_perplexity: 313.4186
#
# Epoch 00008: val_loss did not improve from 5.59397
# Epoch 9/20
# 2323/2323 [==============================] - 151s 65ms/step - loss: 5.9017 - perplexity: 449.8921 - val_loss: 5.6169 - val_perplexity: 295.2101
#
# Epoch 00009: val_loss did not improve from 5.59397
# Epoch 10/20
# 2323/2323 [==============================] - 151s 65ms/step - loss: 5.9199 - perplexity: 456.2481 - val_loss: 5.5922 - val_perplexity: 298.2734
#
# Epoch 00010: val_loss improved from 5.59397 to 5.59223, saving model to drive/My Drive/Deep Learning Course/ex2_301558086_305143315/PTB/Stav/gru.with_drop.model.weights.best.hdf5
# Epoch 11/20
# 2323/2323 [==============================] - 152s 66ms/step - loss: 5.8988 - perplexity: 443.4686 - val_loss: 5.5485 - val_perplexity: 283.5405
#
# Epoch 00011: val_loss improved from 5.59223 to 5.54849, saving model to drive/My Drive/Deep Learning Course/ex2_301558086_305143315/PTB/Stav/gru.with_drop.model.weights.best.hdf5
# Epoch 12/20
# 2323/2323 [==============================] - 151s 65ms/step - loss: 5.9030 - perplexity: 447.6788 - val_loss: 5.5989 - val_perplexity: 300.3444
#
# Epoch 00012: val_loss did not improve from 5.54849
# Epoch 13/20
# 2323/2323 [==============================] - 151s 65ms/step - loss: 5.8801 - perplexity: 440.3888 - val_loss: 5.5619 - val_perplexity: 289.5492
#
# Epoch 00013: val_loss did not improve from 5.54849
# Epoch 14/20
# 2323/2323 [==============================] - 151s 65ms/step - loss: 5.8795 - perplexity: 438.6094 - val_loss: 5.5417 - val_perplexity: 280.9258
#
# Epoch 00014: val_loss improved from 5.54849 to 5.54171, saving model to drive/My Drive/Deep Learning Course/ex2_301558086_305143315/PTB/Stav/gru.with_drop.model.weights.best.hdf5
# Epoch 15/20
# 2323/2323 [==============================] - 151s 65ms/step - loss: 5.8254 - perplexity: 417.5767 - val_loss: 5.5699 - val_perplexity: 287.2832
#
# Epoch 00015: val_loss did not improve from 5.54171
# Epoch 16/20
# 2323/2323 [==============================] - 151s 65ms/step - loss: 5.8443 - perplexity: 429.6996 - val_loss: 5.5851 - val_perplexity: 295.7364
#
# Epoch 00016: val_loss did not improve from 5.54171
# Epoch 17/20
# 2323/2323 [==============================] - 152s 65ms/step - loss: 5.8166 - perplexity: 418.1523 - val_loss: 5.5262 - val_perplexity: 283.5109
#
# Epoch 00017: val_loss improved from 5.54171 to 5.52621, saving model to drive/My Drive/Deep Learning Course/ex2_301558086_305143315/PTB/Stav/gru.with_drop.model.weights.best.hdf5
# Epoch 18/20
# 2323/2323 [==============================] - 153s 66ms/step - loss: 5.8327 - perplexity: 429.3499 - val_loss: 5.5515 - val_perplexity: 285.7023
#
# Epoch 00018: val_loss did not improve from 5.52621
# Epoch 19/20
# 2323/2323 [==============================] - 153s 66ms/step - loss: 5.8252 - perplexity: 425.9415 - val_loss: 5.5436 - val_perplexity: 289.2992
#
# Epoch 00019: val_loss did not improve from 5.52621
# Epoch 20/20
# 2323/2323 [==============================] - 152s 65ms/step - loss: 5.8004 - perplexity: 414.0071 - val_loss: 5.5363 - val_perplexity: 276.2597
#
# Epoch 00020: val_loss did not improve from 5.52621
#
#  Training data:
# Actual words: chairman of consolidated gold fields plc was named a nonexecutive
# Predicted words: <unk> of the <unk> corp. <unk> <eos> <unk> president <unk>
#
#  Validation data:
# Actual words: on various <unk> issues <eos> and the new syndicated reality
# Predicted words: <eos> the <unk> <eos> <eos> the the <unk> york <unk>
#
#  Test data:
# Actual words: unable to cool the selling panic in both stocks and
# Predicted words: <eos> to be the <unk> <eos> <eos> the <eos> <eos>
#
#  Training set evaluation:
# 2323/2323 [==============================] - 69s 30ms/step
#
#  Validation set evaluation:
# 184/184 [==============================] - 6s 31ms/step
#
#  Testing set evaluation:
# 206/206 [==============================] - 6s 30ms/step
#
#  Best Model Results:
# Training set perplexity: 251.12868617256376
# Validation set perplexity: 265.31278079688974
# Testing set perplexity: 268.2319290988258

# %% [markdown]
# # Load and Evaluate Saved Models
# 1. Run all code sets in the **Initialize** section above.
# 2. Mount your **Drive** and define the right **data_path** to the PTB folder, where is the data and trained models are stored.
# 3. Run the **Check Models** section - this is defined to evaluate all the 4 required models, present a prediction example and the perplexity measure of both the training and testing sets.

# %% [markdown]
# ## Mount Drive

# %%
from google.colab import drive
drive.mount('/content/drive/')

# %% [markdown]
# ## Specify PTB Data Path

# %%
data_path = "drive/My Drive/Deep Learning Course/ex2_301558086_305143315/PTB/"
name = '/Stav'

# %% [markdown]
# ## Check Models

# %%
check_model(train_data, valid_data, test_data, vocabulary, reversed_dictionary, data_path, name, net='lstm', drp=0., num_steps=20)
plot_acc_lss(data_path, name, net='lstm', drp=0.)
check_model(train_data, valid_data, test_data, vocabulary, reversed_dictionary, data_path, name, net='lstm', drp=0.3, num_steps=20)
plot_acc_lss(data_path, name, net='lstm', drp=0.5)
check_model(train_data, valid_data, test_data, vocabulary, reversed_dictionary, data_path, name, net='gru', drp=0., num_steps=20)
plot_acc_lss(data_path, name, net='gru', drp=0.)
check_model(train_data, valid_data, test_data, vocabulary, reversed_dictionary, data_path, name, net='gru', drp=0.3, num_steps=20)
plot_acc_lss(data_path, name, net='gru', drp=0.5)
# Out:
#  Training data:
# Actual words: chairman of consolidated gold fields plc was named a nonexecutive
# Predicted words: president of the <unk> corp. a a named president <unk>
#
#  Validation data:
# Actual words: on various <unk> issues <eos> and the new syndicated reality
# Predicted words: to the <unk> <eos> <eos> the the company york <unk>
#
#  Test data:
# Actual words: unable to cool the selling panic in both stocks and
# Predicted words: <eos> to <unk> the <unk> of <eos> the the <eos>
#
#  Training set evaluation:
# 2323/2323 [==============================] - 55s 24ms/step
#
#  Validation set evaluation:
# 184/184 [==============================] - 4s 24ms/step
#
#  Testing set evaluation:
# 206/206 [==============================] - 5s 24ms/step
#
#  Best Model Results:
# Training set perplexity: 128.712821076108
# Validation set perplexity: 232.75888726878588
# Testing set perplexity: 202.55908005074744
#  Training data:
# Actual words: chairman of consolidated gold fields plc was named a nonexecutive
# Predicted words: chief of the <unk> corp. <eos> <eos> named president vice
#
#  Validation data:
# Actual words: on various <unk> issues <eos> and the new syndicated reality
# Predicted words: to the <unk> <eos> <eos> the the <unk> york <unk>
#
#  Test data:
# Actual words: unable to cool the selling panic in both stocks and
# Predicted words: <eos> to be the <unk> of <eos> the <unk> <eos>
#
#  Training set evaluation:
# 2323/2323 [==============================] - 56s 24ms/step
#
#  Validation set evaluation:
# 184/184 [==============================] - 4s 24ms/step
#
#  Testing set evaluation:
# 206/206 [==============================] - 5s 24ms/step
#
#  Best Model Results:
# Training set perplexity: 170.6360754208834
# Validation set perplexity: 226.93821759215206
# Testing set perplexity: 203.28260977867419
#  Training data:
# Actual words: chairman of consolidated gold fields plc was named a nonexecutive
# Predicted words: chairman of the <unk> corp. <unk> 's a <unk> <unk>
#
#  Validation data:
# Actual words: on various <unk> issues <eos> and the new syndicated reality
# Predicted words: to the <unk> and <eos> the the <unk> york <unk>
#
#  Test data:
# Actual words: unable to cool the selling panic in both stocks and
# Predicted words: <eos> to <unk> the <unk> of <eos> the the <eos>
#
#  Training set evaluation:
# 2323/2323 [==============================] - 55s 24ms/step
#
#  Validation set evaluation:
# 184/184 [==============================] - 4s 24ms/step
#
#  Testing set evaluation:
# 206/206 [==============================] - 5s 25ms/step
#
#  Best Model Results:
# Training set perplexity: 173.00869202690384
# Validation set perplexity: 225.12322701713512
# Testing set perplexity: 223.65837381878006
#  Training data:
# Actual words: chairman of consolidated gold fields plc was named a nonexecutive
# Predicted words: <unk> of the <unk> corp. <eos> <eos> named president <unk>
#
#  Validation data:
# Actual words: on various <unk> issues <eos> and the new syndicated reality
# Predicted words: in the <unk> <eos> <eos> the the <unk> york <unk>
#
#  Test data:
# Actual words: unable to cool the selling panic in both stocks and
# Predicted words: <eos> to be the <unk> of <eos> the the <eos>
#
#  Training set evaluation:
# 2323/2323 [==============================] - 56s 24ms/step
#
#  Validation set evaluation:
# 184/184 [==============================] - 4s 24ms/step
#
#  Testing set evaluation:
# 206/206 [==============================] - 5s 24ms/step
#
#  Best Model Results:
# Training set perplexity: 178.46426400447558
# Validation set perplexity: 228.91434933823558
# Testing set perplexity: 213.78484133882395
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-a15ecbf9d1af> in <module>()
#       7 check_model(train_data, valid_data, test_data, vocabulary, reversed_dictionary, data_path, name, net='gru', drp=0.3, num_steps=20)
#       8 plot_acc_lss(data_path, name, net='gru', drp=0.5)
# ----> 9 plot_all(data_path)
#
# NameError: name 'plot_all' is not defined

# %%
plot_all(data_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-d79c6ea71fa1> in <module>()
# ----> 1 plot_all(data_path)
#
# <ipython-input-1-c1ec505c8f40> in plot_all(data_path)
#      84
#      85 def plot_all(data_path):
# ---> 86   lstm = pd.read_csv(data_path+'/Stav/lstm.without_drop.history.csv')
#      87   lstm_drp = pd.read_csv(data_path+'/Stav/lstm.with_drop.history.csv')
#      88   gru = pd.read_csv(data_path+'/Stav/gru.without_drop.history.csv')
#
# NameError: name 'pd' is not defined
